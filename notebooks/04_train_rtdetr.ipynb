# %% [markdown]
# # 04b — RT-DETR Training (5-Fold Cross-Validation)
#
# Trains **RT-DETR** (Real-Time Detection Transformer, Zhao et al. 2023) on the
# KARTector dataset using the same 5-fold YOLO-format splits as notebook 02.
#
# RT-DETR advantages over vanilla DETR for this use-case:
# - **Converges in 10–50 epochs** (vs 300+ for DETR)
# - Uses the same YOLO-format data pipeline — no annotation conversion needed
# - Available directly via Ultralytics (`rtdetr-l.pt`, `rtdetr-x.pt`)
# - Competitive accuracy with YOLO11 at similar speeds
#
# Prerequisites: `01_prepare_dataset.ipynb`

# %% [markdown]
# ## 0 — Configuration

# %%
from pathlib import Path
from ultralytics import RTDETR
import torch, yaml, json, numpy as np

REPO_ROOT  = Path('../')
YOLO_DIR   = REPO_ROOT / 'data/yolo_dataset_cv_reduced'
RUNS_DIR   = (REPO_ROOT / 'runs' / 'rtdetr').resolve()
RUNS_DIR.mkdir(parents=True, exist_ok=True)
N_FOLDS    = 1

# Model variant: rtdetr-l (lighter) or rtdetr-x (heavier/more accurate)
MODEL_SIZE = 'rtdetr-l'

# Training hyperparameters
EPOCHS  = 10
IMGSZ   = 640
BATCH   = 8

if torch.cuda.is_available():
    DEVICE = 'cuda'
elif torch.backends.mps.is_available():
    DEVICE = 'mps'
else:
    DEVICE = 'cpu'
print(f'Device: {DEVICE}')

with open(REPO_ROOT / 'data/splits/splits.json') as f:
    splits = json.load(f)
CLASSES = splits['classes']
print(f'Classes: {CLASSES}')
# Out:
# Device: mps
# Classes: ['Boost', 'Charge', 'Defense', 'Glide', 'HP', 'Offense', 'Top Speed', 'Turn', 'Weight']

# %% [markdown]
# ## 0b — Diagnostics Helpers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

_COLORS = plt.cm.tab20.colors


def plot_all_folds_diagnostics(runs_dir, n_folds, final=True):
    """Overlay train/val loss curves for all folds + final model."""
    runs_dir = Path(runs_dir)
    fold_colors = plt.cm.tab10.colors
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle('RT-DETR CV Folds — Training Curves', fontweight='bold')
    col_titles = ['Box/GIoU Loss (train)', 'mAP@50', 'mAP@50:95']
    col_keys = [
        # RT-DETR uses giou_loss; YOLO uses box_loss — accept either
        lambda df: next((c for c in df.columns if ('box_loss' in c or 'giou_loss' in c) and 'train' in c), None),
        lambda df: next((c for c in df.columns if 'mAP50'   in c and '95' not in c), None),
        lambda df: next((c for c in df.columns if 'mAP50-95' in c), None),
    ]
    ylabels = ['Box/GIoU Loss', 'mAP@50', 'mAP@50:95']

    for fold in range(n_folds):
        csv_path = runs_dir / f'fold_{fold}' / 'results.csv'
        if not csv_path.exists(): continue
        df = pd.read_csv(csv_path); df.columns = df.columns.str.strip()
        x = df['epoch'] if 'epoch' in df.columns else range(len(df))
        color = fold_colors[fold % len(fold_colors)]
        for ax, key_fn, title, ylabel in zip(axes, col_keys, col_titles, ylabels):
            col = key_fn(df)
            if col: ax.plot(x, df[col], color=color, lw=2, label=f'Fold {fold}')
            ax.set_title(title); ax.set_xlabel('Epoch'); ax.set_ylabel(ylabel)
            ax.grid(True, alpha=0.3)

    if final:
        csv_final = runs_dir / 'final' / 'results.csv'
        if csv_final.exists():
            df = pd.read_csv(csv_final); df.columns = df.columns.str.strip()
            x = df['epoch'] if 'epoch' in df.columns else range(len(df))
            for ax, key_fn in zip(axes, col_keys):
                col = key_fn(df)
                if col: ax.plot(x, df[col], color='black', lw=2.5, ls='--', label='Final')

    for ax in axes: ax.legend(fontsize=8)
    plt.tight_layout()
    out = runs_dir / 'fold_training_curves.png'
    plt.savefig(out, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'Saved: {out}')


def plot_per_class_ap(run_dir, fold_label, data_yaml, model_path):
    """Per-class AP@50 bar chart for a single RT-DETR model."""
    if not Path(model_path).exists():
        print(f'  [{fold_label}] weights not found — skipping per-class AP'); return None
    m = RTDETR(str(model_path)).val(data=str(Path(data_yaml).resolve()),
                                    imgsz=IMGSZ, device=DEVICE, verbose=False)
    ap_idx  = m.box.ap_class_index.tolist() if hasattr(m.box.ap_class_index, 'tolist') else list(m.box.ap_class_index)
    ap_vals = m.box.ap50.tolist()           if hasattr(m.box.ap50, 'tolist')           else list(m.box.ap50)
    class_labels = [CLASSES[i] for i in ap_idx]

    fig, ax = plt.subplots(figsize=(10, 4))
    bars = ax.bar(class_labels, ap_vals,
                  color=[_COLORS[i % len(_COLORS)] for i in range(len(class_labels))],
                  edgecolor='white')
    for bar, val in zip(bars, ap_vals):
        ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.01,
                f'{val:.3f}', ha='center', fontsize=8, fontweight='bold')
    ax.axhline(y=m.box.map50, color='red', ls='--', lw=1.5, label=f'mAP@50={m.box.map50:.3f}')
    ax.set_ylabel('AP@50'); ax.set_title(f'{fold_label} — Per-Class AP@50', fontweight='bold')
    ax.set_ylim(0, 1.1); ax.legend(); ax.grid(axis='y', alpha=0.3)
    plt.xticks(rotation=30, ha='right'); plt.tight_layout()
    out = Path(run_dir) / 'diagnostics_per_class_ap.png'
    plt.savefig(out, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'  mAP@50={m.box.map50:.4f}  mAP@50:95={m.box.map:.4f}  Saved: {out}')
    return m


def plot_sample_predictions(model_path, val_img_dir, title='Final Model', n=9):
    """Show a 3×3 grid of random val images with predicted bounding boxes.
    val_img_dir may be a directory of images OR a .txt manifest file.
    """
    val_img_dir = Path(val_img_dir)
    if val_img_dir.suffix == '.txt':
        imgs = [Path(p) for p in val_img_dir.read_text().splitlines() if p.strip()]
        imgs = sorted([p for p in imgs if p.suffix.lower() in ('.jpg', '.jpeg', '.png')])
    else:
        imgs = sorted([p for p in val_img_dir.iterdir()
                       if p.suffix.lower() in ('.jpg', '.jpeg', '.png')])
    if not imgs:
        print(f'  No images found in {val_img_dir}'); return

    model = RTDETR(str(model_path))
    np.random.seed(42)
    chosen = [imgs[i] for i in np.random.choice(len(imgs), min(n, len(imgs)), replace=False)]

    cols = 3
    rows_n = (len(chosen) + cols - 1) // cols
    fig, axes = plt.subplots(rows_n, cols, figsize=(cols*5, rows_n*4))
    axes = np.array(axes).flatten()
    fig.suptitle(f'{title} — Sample Predictions', fontweight='bold')

    for ax, img_path in zip(axes, chosen):
        res = model.predict(str(img_path), conf=0.25, verbose=False)
        ax.imshow(res[0].plot()[:, :, ::-1])
        ax.set_title(f'{len(res[0].boxes)} detections', fontsize=9)
        ax.axis('off')
    for ax in axes[len(chosen):]: ax.axis('off')

    plt.tight_layout()
    out = Path(model_path).parent.parent / 'sample_predictions.png'
    plt.savefig(out, dpi=120, bbox_inches='tight')
    plt.show()
    print(f'  Saved: {out}')


print('Diagnostics helpers ready.')
# Out:
# Diagnostics helpers ready.

# %% [markdown]
# ## 1 — 5-Fold Training

# %%
fold_results = {}

for fold in range(N_FOLDS):
    data_yaml = YOLO_DIR / f'fold_{fold}' / 'data.yaml'
    if not data_yaml.exists():
        print(f'Fold {fold}: data.yaml missing — run 01_prepare_dataset first')
        continue

    print(f"\n{'='*50}")
    print(f'Fold {fold}/{N_FOLDS}  ({MODEL_SIZE}, {EPOCHS} epochs)')
    print(f"{'='*50}")

    model = RTDETR(f'{MODEL_SIZE}.pt')
    results = model.train(
        data     = str(data_yaml.resolve()),
        epochs   = EPOCHS,
        imgsz    = IMGSZ,
        batch    = BATCH,
        device   = DEVICE,
        project  = str(RUNS_DIR),
        name     = f'fold_{fold}',
        exist_ok = True,
        plots    = True,
        val      = True,
        workers  = 0,
    )
    fold_results[fold] = {
        'map50':    results.results_dict.get('metrics/mAP50(B)', 0),
        'map50_95': results.results_dict.get('metrics/mAP50-95(B)', 0),
        'weights':  str(RUNS_DIR / f'fold_{fold}' / 'weights' / 'best.pt'),
    }
    print(f'Fold {fold} mAP@0.5: {fold_results[fold]["map50"]:.4f}')

print('\nFold summary:')
maps = [v['map50'] for v in fold_results.values()]
print(f'  mAP@0.5  mean={np.mean(maps):.4f}  std={np.std(maps):.4f}  '
      f'min={min(maps):.4f}  max={max(maps):.4f}')

plot_all_folds_diagnostics(RUNS_DIR, N_FOLDS, final=False)
# Out:
# ==================================================
# Fold 0/1  (rtdetr-l, 10 epochs)
# ==================================================
# New https://pypi.org/project/ultralytics/8.4.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.40 🚀 Python-3.12.8 torch-2.11.0 CPU (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/joh11678/.ws/KARTector/data/yolo_dataset_cv_reduced/fold_0/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=10, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=rtdetr-l.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=fold_0, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/Users/joh11678/.ws/KARTector/runs/rtdetr, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/joh11678/.ws/KARTector/runs/rtdetr/fold_0, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=9
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1     25248  ultralytics.nn.modules.block.HGStem          [3, 32, 48]
#   1                  -1  6    155072  ultralytics.nn.modules.block.HGBlock         [48, 48, 128, 3, 6]
#   2                  -1  1      1408  ultralytics.nn.modules.conv.DWConv           [128, 128, 3, 2, 1, False]
#   3                  -1  6    839296  ultralytics.nn.modules.block.HGBlock         [128, 96, 512, 3, 6]
#   4                  -1  1      5632  ultralytics.nn.modules.conv.DWConv           [512, 512, 3, 2, 1, False]
#   5                  -1  6   1695360  ultralytics.nn.modules.block.HGBlock         [512, 192, 1024, 5, 6, True, False]
#   6                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   7                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   8                  -1  1     11264  ultralytics.nn.modules.conv.DWConv           [1024, 1024, 3, 2, 1, False]
#   9                  -1  6   6708480  ultralytics.nn.modules.block.HGBlock         [1024, 384, 2048, 5, 6, True, False]
#  10                  -1  1    524800  ultralytics.nn.modules.conv.Conv             [2048, 256, 1, 1, None, 1, 1, False]
#  11                  -1  1    789760  ultralytics.nn.modules.transformer.AIFI      [256, 1024, 8]
#  12                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14                   7  1    262656  ultralytics.nn.modules.conv.Conv             [1024, 256, 1, 1, None, 1, 1, False]
#  15            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  17                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  18                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  19                   3  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1, None, 1, 1, False]
#  20            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  22                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  23            [-1, 17]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  25                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  26            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  27                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  28        [21, 24, 27]  1   7320347  ultralytics.nn.modules.head.RTDETRDecoder    [9, [256, 256, 256]]
# rt-detr-l summary: 465 layers, 32,824,571 parameters, 32,824,571 gradients, 108.0 GFLOPs
#
# Transferred 926/941 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 434.4±26.2 MB/s, size: 115.6 KB)
# train: Scanning /Users/joh11678/.ws/KARTector/data/yolo_dataset_cv_reduced/labels... 6596 images, 607 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6596/6596 6.7Kit/s 1.0s0.1s
# train: New cache created: /Users/joh11678/.ws/KARTector/data/yolo_dataset_cv_reduced/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 366.6±85.2 MB/s, size: 105.4 KB)
# val: Scanning /Users/joh11678/.ws/KARTector/data/yolo_dataset_cv_reduced/labels... 1498 images, 150 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1498/1498 6.8Kit/s 0.2s0.0s
# val: New cache created: /Users/joh11678/.ws/KARTector/data/yolo_dataset_cv_reduced/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000769, momentum=0.9) with parameter groups 143 weight(decay=0.0), 206 weight(decay=0.0005), 226 bias(decay=0.0)
# Plotting labels to /Users/joh11678/.ws/KARTector/runs/rtdetr/fold_0/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/joh11678/.ws/KARTector/runs/rtdetr/fold_0
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#        1/10         0G      1.828      72.56     0.7828          9        640: 0% ──────────── 3/825 6.0s/it 28.8s<1:22:166
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      10     print(f'Fold {fold}/{N_FOLDS}  ({MODEL_SIZE}, {EPOCHS} epochs)')
#      11     print(f"{'='*50}")
#      12
#      13     model = RTDETR(f'{MODEL_SIZE}.pt')
# ---> 14     results = model.train(
#      15         data     = str(data_yaml.resolve()),
#      16         epochs   = EPOCHS,
#      17         imgsz    = IMGSZ,
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:788, in Model.train(self, trainer, **kwargs)
#     785     self.trainer.model = self.trainer.get_model(weights=self.model, cfg=self.model.yaml)
#     786     self.model = self.trainer.model
# --> 788 self.trainer.train()
#     789 # Update model and cfg after training
#     790 if RANK in {-1, 0}:
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/engine/trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/engine/trainer.py:439, in BaseTrainer._do_train(self)
#     437     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     438 else:
# --> 439     loss, self.loss_items = self.model(batch)
#     440 self.loss = loss.sum()
#     441 if RANK != -1:
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:141, in BaseModel.forward(self, x, *args, **kwargs)
#     128 """Perform forward pass of the model for either training or inference.
#     129
#     130 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    138     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     139 """
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 141     return self.loss(x, *args, **kwargs)
#     142 return self.predict(x, *args, **kwargs)
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:796, in RTDETRDetectionModel.loss(self, batch, preds)
#     788 targets = {
#     789     "cls": batch["cls"].to(img.device, dtype=torch.long).view(-1),
#     790     "bboxes": batch["bboxes"].to(device=img.device),
#     791     "batch_idx": batch_idx.to(img.device, dtype=torch.long).view(-1),
#     792     "gt_groups": gt_groups,
#     793 }
#     795 if preds is None:
# --> 796     preds = self.predict(img, batch=targets)
#     797 dec_bboxes, dec_scores, enc_bboxes, enc_scores, dn_meta = preds if self.training else preds[1]
#     798 if dn_meta is None:
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:837, in RTDETRDetectionModel.predict(self, x, profile, visualize, batch, augment, embed)
#     835 if profile:
#     836     self._profile_one_layer(m, x, dt)
# --> 837 x = m(x)  # run
#     838 y.append(x if m.i in self.save else None)  # save output
#     839 if visualize:
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:180, in HGBlock.forward(self, x)
#     178 """Forward pass of a PPHGNetV2 backbone layer."""
#     179 y = [x]
# --> 180 y.extend(m(y[-1]) for m in self.m)
#     181 y = self.ec(self.sc(torch.cat(y, 1)))
#     182 return y + x if self.add else y
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:180, in <genexpr>(.0)
#     178 """Forward pass of a PPHGNetV2 backbone layer."""
#     179 y = [x]
# --> 180 y.extend(m(y[-1]) for m in self.m)
#     181 y = self.ec(self.sc(torch.cat(y, 1)))
#     182 return y + x if self.add else y
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:182, in LightConv.forward(self, x)
#     173 def forward(self, x):
#     174     """Apply 2 convolutions to input tensor.
#     175
#     176     Args:
#    (...)    180         (torch.Tensor): Output tensor.
#     181     """
# --> 182     return self.conv2(self.conv1(x))
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)     76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:553, in Conv2d.forward(self, input)
#     552 def forward(self, input: Tensor) -> Tensor:
# --> 553     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.ws/KARTector/.venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548, in Conv2d._conv_forward(self, input, weight, bias)
#     535 if self.padding_mode != "zeros":
#     536     return F.conv2d(
#     537         F.pad(
#     538             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    545         self.groups,
#     546     )
# --> 548 return F.conv2d(
#     549     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     550 )
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2 — Final Model (all 80% data)

# %%
full_yaml = YOLO_DIR / 'full_train' / 'data.yaml'
print(f'Training final model on: {full_yaml}')

final_model = RTDETR(f'{MODEL_SIZE}.pt')
final_results = final_model.train(
    data     = str(full_yaml.resolve()),
    epochs   = EPOCHS,
    imgsz    = IMGSZ,
    batch    = BATCH,
    device   = DEVICE,
    project  = str(RUNS_DIR),
    name     = 'final',
    exist_ok = True,
    plots    = True,
    val      = True,
    workers  = 0,
)
print(f"Final model mAP@0.5: {final_results.results_dict.get('metrics/mAP50(B)',0):.4f}")
final_weights = RUNS_DIR / 'final' / 'weights' / 'best.pt'
print(f'Weights: {final_weights}')

plot_all_folds_diagnostics(RUNS_DIR, N_FOLDS, final=True)

plot_per_class_ap(
    run_dir    = RUNS_DIR / 'final',
    fold_label = 'Final Model',
    data_yaml  = full_yaml,
    model_path = str(final_weights),
)

val_img_dir = YOLO_DIR / 'full_train' / 'val.txt'
if not val_img_dir.exists():
    val_img_dir = YOLO_DIR / 'fold_0' / 'val.txt'
plot_sample_predictions(
    model_path  = str(final_weights),
    val_img_dir = val_img_dir,
    title       = 'Final RT-DETR',
    n           = 9,
)
